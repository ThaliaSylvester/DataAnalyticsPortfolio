# %% [markdown]
# # <p style="text-align: center;">MIS 304 </p>
# # <p style="text-align: center;">Assignment 6 </p>
# ## <p style="text-align: center;">Total points: 100</p>
# ## <p style="text-align: center;">Due: Monday, November 29</p>

# %% [markdown]
# **Question 1**    50 pts

# %% [markdown]
# **Write an Employee class that has the following attributes:**
# * A)	Employee name (string)
# * B)    Employee id (integer)
# * C)	Hourly rate (float)
# * D)	Hours worked per week (float)
#
# Your class should have the following basic methods:
# * A)	__init__
# * B)	__str__ that will output the values of all attributes
# * C)	update_hourly_rate that updates the value of the employee's hourly rate
# * D)    update_weekly_hours_worked that updates the total of hours an employee has worked during the week
# * E)	Calculate salary that does not accept any arguments except for self. The salary is calculated by multiplying hours worked by hourly rate. The method will return the salary.
#
# *Clarification for C and D: If an employee instance has hourly rate of 20 dollars/hr, and that employee gets a promotion we can set his/her salary to 35 dollars/hr by setting the hourly rate to be 35 through the update hourly rate. Similarly you can change the total amount of hours an employee has worked for that week.*
#
#
# The rules for setting hourly rate and hours worked are the following:
# * Hourly rate at the company must be at least 7.50 and cannot exceed 70.00. An invalid hourly rate should not be assigned to the class attributes. Instead, your program should output the error message: 'The new hourly rate is out of acceptable range. Value not updated'
# *	Each employee must work at least 5 hours a week and cannot exceed 40 hours a week. An invalid hours worked should not be assigned to the class attributes. Instead, your program should output the error message: 'The new entry for hours worked is out of range. Value not updated'

# %%
# write your code here:

# %%
# 1. Instantiate the class by creating one Employee instance

# %%
# 2. Print the object

# %%
# 3. Show the employee_id attribute

# %%
# 4. calculate the salary of the object you created

# %%
# update the working hours of the object to be more than 40 and get an error message in return

# %%
# update the working hours of the object to be less than 7.5 and get an error message in return

# %% [markdown]
# **Question 2**    40 pts

# %% [markdown]
# **Play the game of Rock, Paper, Scissors !**

# %% [markdown]
# * Step 1: Computer makes a selection

# %%
# import the random package. Use this to get the computer's choice of one of the three options available
import random

# %%
#use random.choice() to have the computer randomly select between the options:

possible_options = ["rock", "paper", "scissors"]

# random.choice(possible_options) will allow the computer to randomly choose one of the three options

# %% [markdown]
# * Step 2: The user makes a selection between the three options. Keep asking for a selection that is valid (for example, if you ask the user to enter 1 for Rock, 2 for paper and 3 for Scissors any input different than these is invalid.

# %%
# use input() to get the user's selection and assign it to a variable. Check if the user gives a valid response

# %%
# Time for declaring the winner! Check for a tie or declare the winner according to the game rules:
#Rock smashes scissors
#Paper covers rock
#Scissors cut paper
# if both players select the same then it's a tie

# %% [markdown]
# * Step 3: Declare the winner in a fun print statement
#
#   For example: Scissors cuts paper! You win!

# %%
# you can write all your game code here:

# %% [markdown]
# **Question 3**    10 pts

# %% [markdown]
# Figure out a way to tweak the code above, so you can keep playing Rock,Paper,Scissors with the computer until you decide to quit. You will need a loop for this and some sort of exit condition. So as long as the condition in the loop is True, you get asked again to make a choice and you keep playing. Once that condition is False you exit the loop. Useful things to remember are: the while loop and the break condition. You can do this with more than one way, be creative and have fun!

# %%
# write your code here:
